# %% [markdown]
# <a href="https://colab.research.google.com/github/SJcodeML/-Python-class-5-to-6-30/blob/main/practice_questions_on_operators_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LOGICAL OPERATORS

# %%
1- Predict the final value of `x` after the following code runs. Explain the mechanism (**short-circuiting**) that prevents the code from raising a `ZeroDivisionError` and determines the flow of execution.


x = 10
y = 0

if y and (x / y):
    x = 100
else:
    x = 50

print(f"Final x: {x}")

# %%
### 2\. Truthiness and Return Values (Short-Circuiting)

**Question:** Python's logical operators often return one of the operands, not just a simple boolean. Predict the output for the three lines below. State the specific rule that determines which operand is returned for the `or` operator in `result_2`.

```python
print(f"1. result_1 = {3 and 0}")
print(f"2. result_2 = {[] or 'Found'}")
print(f"3. result_3 = {'' and 99}")
```

| Line | Predicted Output |
| :--- | :--------------- |
| 1 | |
| 2 | |
| 3 | |

**Rule for `or` based on Line 2:**

-----

# %%
### 3\. Precedence: `not`, `and`, and `or`

**Question:** The precedence order for logical operators is **`not` (highest) $\rightarrow$ `and` $\rightarrow$ `or` (lowest)**. Given the expression below, place parentheses to explicitly show the order of evaluation and then predict the final output.

```python
p = True
q = False
r = True

result = p or not q and r
print(result)
```

**Evaluation with Parentheses:**
`result = (p or ((not q) and r))`

**Step-by-Step Evaluation:**

1.  `not q`:
2.  $\rightarrow$ Result of `and`:
3.  $\rightarrow$ Result of `or`:

**Predicted Output:**

-----

# %%
### 4\. Logical NOT (`not`) on Different Data Types

**Question:** The `not` operator relies on **truthiness**  and always returns a pure boolean (`True` or `False`). Predict the output for the three lines below, explaining why an empty string, an empty tuple, and the number one produce the results they do.

```python
a = ""
b = (1, 2)
c = ()

print(f"1. {not a}")
print(f"2. {not b}")
print(f"3. {not c}")
```

**Explanation:**

-----

# %%
### 5\. Walrus Operator (`:=`) and Short-Circuiting

**Question:** The Walrus Operator (`:=`) allows assignment within an expression. Predict the final values of `count` and `flag` after the following conditional statement executes.

```python
flag = False
count = 0

if flag or (count := 5):
    pass

print(f"Final flag: {flag}")
print(f"Final count: {count}")
```

**Explanation:** Why was `count` successfully assigned the value of `5`? Relate your answer to the short-circuiting behavior of the `or` operator.

-----

# %%
### 6\. Combining Logical and Comparison Operators (Complex Condition)

**Question:** Analyze the following expression designed to determine if a user should be granted access. Predict the value of the `access_granted` variable and show the step-by-step boolean evaluation.

```python
age = 17
has_parent_approval = True
is_vip = False

# Access is granted if (age >= 18 OR has_parent_approval) AND NOT is_vip
access_granted = (age >= 18 or has_parent_approval) and not is_vip

print(f"Access Granted: {access_granted}")
```

**Step-by-Step Boolean Evaluation:**

1.  `age >= 18`:
2.  `has_parent_approval`:
3.  `is_vip`:
4.  $\rightarrow$ Result of `or`:
5.  $\rightarrow$ Result of `not`:
6.  $\rightarrow$ Final `and` result:

-----

# %% [markdown]
# ASSIGNMENT OPERATORS

# %%
### 1\. Data Type Evolution (The `/=`)

**Question:** Starting with an integer variable `x`, track its value and data type through the following operations. Predict the final output for both the value and its type.

```python
x = 10
print(f"Initial: Value={x}, Type={type(x).__name__}")

x += 5
print(f"After x += 5: Value={x}, Type={type(x).__name__}")

x /= 3
print(f"After x /= 3: Value={x}, Type={type(x).__name__}")
```

| Step | Value of `x` | Type of `x` |
| :--- | :----------- | :---------- |
| Initial | 10 | int |
| After `x += 5` | | |
| After `x /= 3` | | |

-----

# %%
### 2\. Compound Assignment with Floats and Integers (`//=`)

**Question:** The Floor Division Assignment operator (`//=`) is used below. Determine the final value of `a`. Explain why the result is a float, even though floor division usually produces an integer result.

```python
a = 15.5
a //= 4
print(f"Final value of a: {a}")
print(f"Final type of a: {type(a).__name__}")
```

**Final Value:**

**Explanation for Type:**

-----

# %%
### 3\. Exponentiation Assignment (`**=`)

**Question:** Trace the value of the variable `z` through the following sequence of assignment operations.

```python
z = 2
z **= 3     # Operation 1
z *= 5      # Operation 2
print(z)
```

| Operation | Equivalent to | Value of `z` |
| :--- | :--- | :--- |
| Initial | | 2 |
| 1. `z **= 3` | `z = z ** 3` | |
| 2. `z *= 5` | `z = z * 5` | |

-----

# %%
### 4\. Assignment with Mutable Types (List Concatenation)

**Question:** When applying the Addition Assignment operator (`+=`) to a list, it performs an *in-place extension* (like `extend()`), rather than creating a new list. Predict the final state of both `list_a` and `list_b` and explain the result of the final `is` check.

```python
list_a = [1, 2]
list_b = list_a  # Both variables point to the same list object in memory

list_a += [3, 4]

print(f"list_a: {list_a}")
print(f"list_b: {list_b}")
print(f"list_a is list_b: {list_a is list_b}")
```

**Explanation for `list_a is list_b`:**

-----

# %%
### 5\. Order of Operations in Compound Assignment (`-=` and `*`)

**Question:** The compound assignment operators operate on the variable first, then evaluate the expression. Calculate the final value of `y` in the following code block, showing the value of `y` after the single assignment line.

```python
x = 5
y = 20

# The expression (x * 2) is evaluated first, then the assignment occurs.
y -= x * 2

print(y)
```

**Show your steps:**

1.  Evaluate the expression: $x * 2 = ?$
2.  Perform the assignment: $y = y - (\text{result from step 1}) = ?$

-----

# %%
### 6\. The Modulus Assignment Operator (`%=`)

**Question:** The Modulus Assignment operator (`%=`) is often used in programming to constrain a number to a certain range or cycle. Trace the value of `timer` through the sequence of operations below, which simulates a 12-hour clock.

```python
timer = 11  # 11 o'clock

# Operation 1: Advance by 3 hours
timer += 3
print(f"After +3: {timer}")

# Operation 2: Cycle the clock using Modulus Assignment
timer %= 12
print(f"After %= 12: {timer}")
```

| Operation | Value of `timer` |
| :--- | :--- |
| Initial | 11 |
| 1. `timer += 3` | |
| 2. `timer %= 12` | |

-----

# %% [markdown]
# WALRUS OPERATOR

# %%
### 1\. Basic Syntax and Evaluation

**Question:** Predict the final value of both `x` and `result` in the code below. Explain why the Walrus Operator is useful in this specific one-line scenario.

```python
result = 10 + (x := 5) * 2
print(f"x: {x}")
print(f"result: {result}")
```

| Variable | Predicted Value |
| :--- | :--- |
| `x` | |
| `result` | |

**Explanation of Usefulness:**

-----

# %%
### 2\. The Walrus Operator in a `while` loop (The Classic Use Case)

**Question:** The following code iterates through a list, processing elements until it finds the number 5. Rewrite the entire `while` loop using the Walrus Operator to combine the operation of getting the next element and checking the loop condition into a single, more concise line.

**Original Code:**

```python
data = [1, 2, 8, 5, 9, 3]
i = 0
current_value = data[i]
while current_value != 5:
    print(f"Processing: {current_value}")
    i += 1
    current_value = data[i]
```

**Rewritten Code using `:=`:**
(Assume `i` is managed externally or use a different loop structure for maximum conciseness)

-----

# %%
### 3\. Walrus Operator in a Conditional `if` Statement

**Question:** The code below checks if a list is non-empty before processing it. Rewrite the `if` block using the Walrus Operator to assign the length of the list to a variable (`n`) **and** check the condition in one line, eliminating the redundant call to `len(data)`.

**Original Code:**

```python
data = [10, 20, 30]
if len(data) > 0:
    n = len(data)
    print(f"Data has {n} elements.")
else:
    print("Data is empty.")
```

**Rewritten Code using `:=`:**

-----

# %%
### 4\. Scope and Naming (`:=` vs. Traditional Assignment)

**Question:** When the Walrus Operator is used within a conditional statement (`if` block), the assigned variable is generally available outside the block. What will the following code print? Explain how the scope of the variable `total` demonstrates a key difference between `:=` and traditional variable definition within an `if` block in some other languages.

```python
data = [10, 20]
if (total := sum(data)) > 15:
    print(f"A. Inside check: Total is {total}")

print(f"B. Outside check: Total is {total}")
```

**Explanation of Scope:**

-----

# %%
### 5\. Walrus Operator and Logical Operators (Truthiness)

**Question:** The Walrus Operator works well with Python's logical operators. Predict the value of `final_score` and the final value of the assigned variable `x` after the following line of code executes, based on the rules of **truthiness** and short-circuiting.

```python
# The 'or' operator short-circuits to the first True/truthy value.
final_score = 0 or (x := 80)
print(f"final_score: {final_score}")
print(f"x: {x}")
```

**Explanation for `x`'s value:**

-----

# %%
### 6\. Walrus Operator and Syntax Limitations

**Question:** While the Walrus Operator is powerful, it cannot always be used freely. One common restriction is that it cannot be used at the top level of a simple expression (e.g., `x := 5`). Identify the line in the following code that will cause a `SyntaxError` and explain *why* Python disallows this specific use.

```python
# Line 1
# y := 10 + 5

# Line 2
print((z := 20))

# Line 3
if (a := 30) > 25:
    print(a)
```

**Line with Error:**

**Explanation of Syntax Restriction:**

-----

# %% [markdown]
# IDENTITY OPERATORS

# %%
### Question 1: Immutables, Mutables, and Memory Location

Predict the output for each line of code below. Briefly explain why the results for `num_a is num_b` and `list_c is list_d` are different, even though the values are identical in both cases.

```python
# Part 1: Immutable (Integers)
num_a = 100
num_b = 100
print(f"1. num_a is num_b: {num_a is num_b}")

# Part 2: Mutable (Lists)
list_c = [1, 2, 3]
list_d = [1, 2, 3]
print(f"2. list_c is list_d: {list_c is list_d}")
```

| Line | Predicted Output |
| :--- | :--------------- |
| 1 | |
| 2 | |

# %%
### Question 2: The Effect of Assignment and Modification

Analyze the following code block. Predict the output and explain the state of the variables `p` and `q` after the line `q.append(4)` is executed. Why does the second `is` check return the same value as the first?

```python
# Initial Setup
p = [10, 20]
q = p

print(f"1. Initial check (p is q): {p is q}")

# Modification
q.append(4)

print(f"2. After modification (p): {p}")
print(f"3. After modification (p is q): {p is q}")
```

**Explanation:**

-----

# %%
### Question 3: Identity Operator and Common Values

Python sometimes reuses the same memory space for small, commonly used values (like small integers or empty tuples) for optimization . Given the variables below, determine the output of the final two lines based on typical CPython behavior.

```python
small_num_1 = 5
small_num_2 = 5
large_num_1 = 500
large_num_2 = 500

# Prediction is based on typical CPython memory optimization behavior

print(f"1. small_num_1 is small_num_2: {small_num_1 is small_num_2}")
print(f"2. large_num_1 is large_num_2: {large_num_1 is large_num_2}")
```

**Reasoning:**

-----

# %%
### Question 4: Identity with Boolean Keywords

Python's boolean values (`True`, `False`) are unique singleton objects. What will the following code print? Explain the key difference between using the `is` operator and the `not` logical operator in this context.

```python
x = 0
y = ""
z = False

print(f"1. x is not z: {x is not z}")
print(f"2. not x is not z: {not x is not z}")
```

**Hint:** Remember that `0` and `""` evaluate to `False` in a boolean context, but they are not the same *object* as the keyword `False`. Also, consider operator precedence.

-----

# %%
### Question 5: Functions and Identity (Return Values)

Consider the function below, which creates and returns a list. If you call this function multiple times, will the returned objects be the same, or will they be distinct? Predict and explain the output.

```python
def get_list():
    return [1, 2, 3]

list_a = get_list()
list_b = get_list()

print(f"1. list_a == list_b: {list_a == list_b}")
print(f"2. list_a is list_b: {list_a is list_b}")
```

# %%
### Question 6: Unpacking and Shared References

The following code uses sequence unpacking and then modifies one of the variables. Predict the output and use the concept of **shared memory reference** to explain the final value of `a`.

```python
data = [1, 2, 3]
a, b, c = data  # Unpacking

# Now we assign 'data' to 'd' using a simple assignment
d = data

d.append(4)

print(f"1. a is data[0]: {a is data[0]}") # Check if 'a' is the same object as the new list's first element
print(f"2. data: {data}")
print(f"3. d is data: {d is data}")
```

# %% [markdown]
# MEMBERSHIP OPERATORS

# %%
### 1\. Membership in Different Sequence Types

**Question:** Predict the output for the three lines below, which test membership across a list, a tuple, and a set.

```python
data_list = [10, 20, 30]
data_tuple = (100, 200, 300)
data_set = {4, 5, 6}

print(f"1. {20 in data_list}")
print(f"2. {50 not in data_tuple}")
print(f"3. {4 in data_set}")
```

| Line | Sequence Type | Predicted Output |
| :--- | :--- | :--------------- |
| 1 | List | |
| 2 | Tuple | |
| 3 | Set | |

# %%
### 2\. The Nuance of Dictionary Membership

**Question:** When using the `in` operator with a Python dictionary, what part of the dictionary is checked for membership (keys, values, or both)? Predict the output of the two lines below and explain why they are different.

```python
my_dict = {'apple': 5, 'banana': 8}

print(f"1. {'apple' in my_dict}")
print(f"2. {5 in my_dict}")
```

# %%
### 3\. Substring Membership in Strings (Case Sensitivity)

**Question:** The `in` operator can check for substrings within a string. What will the following code print? Explain the concept of **case sensitivity** as it applies to the `in` operator for strings.

```python
text = "Hello Python"

print(f"1. {'Python' in text}")
print(f"2. {'python' in text}")
```

**Explanation of Case Sensitivity:**

-----

# %%
### 4\. Membership Check and Efficiency (List vs. Set)

**Question:** Sets are generally much faster than lists for membership checks (`in`). Explain **why** this is the case at a low level (mentioning hashing or lookup structure) . Given the difference, which of the two checks below is theoretically faster and why?

```python
small_list = [1, 5, 9, 13, 17]
small_set = {1, 5, 9, 13, 17}

# Check A
5 in small_list

# Check B
5 in small_set
```

**Explanation of Efficiency:**

-----

# %%
### 5\. Using `not in` with a Loop Condition

**Question:** The `not in` operator is often used for flow control. Rewrite the following code snippet using a `while` loop and the `not in` operator to achieve the same result.

**Original Code:**

```python
inventory = ["sword", "shield", "potion"]
item = ""

if item not in inventory:
    print("Item is not ready.")
    item = "axe"
    if item not in inventory:
        print("Axe is also not ready.")
```

**Rewritten Code (using a `while` loop that continues as long as a user input `item` is not in `inventory`):**

-----

# %%
### 6\. Membership with Nested Sequences

**Question:** The `in` operator checks for an immediate member, not recursively into nested structures. Predict the output of the two lines below, which deal with a list containing another list.

```python
nested_list = [10, [20, 30], 40]

print(f"1. {20 in nested_list}")
print(f"2. {[20, 30] in nested_list}")
```
